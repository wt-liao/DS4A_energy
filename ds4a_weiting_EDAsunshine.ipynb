# %% [markdown]
# ### DS4A Data Exploration Template

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Set up google drive mount for this notebook, and create global variables for relevant data paths.
# Make sure that you have the DS4A folder added to your own Drive!

from google.colab import drive
drive.mount('/content/drive')

cleandata_path = "/content/drive/My Drive/DS4A/data/Cleaned_feature_data"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Read in sample data as a dataframe
# Feel free to comment out datasets that you don't need
df_sunshine = pd.read_csv(cleandata_path+'/sunshine_clean.csv', index_col=0)

# %%
# We should transform value to a per capita measurement
df_sunshine
# Out:
#              ave sunshine hours per month         std  total data points  \
# AFGHANISTAN                    249.635833   78.883612                240
# ALBANIA                               NaN         NaN                 72
# ARGENTINA                      106.199492  106.408902               1236
# ARMENIA                        204.791667   87.396119                 24
# AUSTRALIA                      115.247135  117.653217                768
# ...                                   ...         ...                ...
# UZBEKISTAN                     236.595833   99.161638                 72
# VENEZUELA                      111.611250  107.583386                480
# YUGOSLAVIA                     187.733333   78.015397                 24
# ZAMBIA                         237.750333   56.558902                300
# ZIMBABWE                       128.863194  122.739082                144
#
#              bad data points
# AFGHANISTAN                0
# ALBANIA                   72
# ARGENTINA                251
# ARMENIA                    0
# AUSTRALIA                  0
# ...                      ...
# UZBEKISTAN                 0
# VENEZUELA                  0
# YUGOSLAVIA                 0
# ZAMBIA                     0
# ZIMBABWE                   0
#
# [117 rows x 4 columns]

# %%
df_sunshine.plot.barh(y=["ave sunshine hours per month", "std"], stacked=True, figsize=(8, 30))
