# %% [markdown]
# ### DS4A Data Exploration Template

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Set up google drive mount for this notebook, and create global variables for relevant data paths.
# Make sure that you have the DS4A folder added to your own Drive!

from google.colab import drive
drive.mount('/content/drive')

data_path = "/content/drive/My Drive/DS4A/data"
# Out:
# Mounted at /content/drive

# %%
# Read in sample data as a dataframe
# Feel free to comment out datasets that you don't need
df = pd.read_csv(data_path + "/UNdata_SunShine.csv")

# %%
# We should transform value to a per capita measurement
df
# Out:
#                Country or Territory      Station Name  WMO Station Number  \
# 0     AFGHANISTAN, ISLAMIC STATE OF         Faiz abad               40904
# 1     AFGHANISTAN, ISLAMIC STATE OF        Sheberghan               40908
# 2     AFGHANISTAN, ISLAMIC STATE OF    Mazar-i-Sharif               40911
# 3     AFGHANISTAN, ISLAMIC STATE OF            Kunduz               40913
# 4     AFGHANISTAN, ISLAMIC STATE OF           Maimana               40922
# ...                             ...               ...                 ...
# 1957                       ZIMBABWE  Bulawayo Airport               67965
# 1958                       ZIMBABWE          Masvingo               67975
# 1959                       ZIMBABWE          Masvingo               67975
# 1960                       ZIMBABWE          Chipinge               67983
# 1961                       ZIMBABWE          Chipinge               67983
#
#      National Station Id Number     Period Element-Statistic Qualifier Code  \
# 0                           NaN  1964-1983                              NaN
# 1                           NaN  1964-1983                              NaN
# 2                           NaN  1959-1983                              NaN
# 3                           NaN  1958-1983                              NaN
# 4                           NaN  1959-1983                              NaN
# ...                         ...        ...                              ...
# 1957                   00PH6986  1961-1990                             NCDC
# 1958                   00TN7681  1961-1990                                6
# 1959                   00TN7681  1961-1990                             NCDC
# 1960                   00VN6167  1961-1990                                6
# 1961                   00VN6167  1961-1990                             NCDC
#
#      Statistic Description Unit    Jan  Jan Footnotes  ...    Oct  \
# 0     Mean Number of Hours    *  117.3            NaN  ...  224.2
# 1     Mean Number of Hours    *  115.3            NaN  ...  242.9
# 2     Mean Number of Hours    *  122.2            NaN  ...  223.2
# 3     Mean Number of Hours    *  114.4            NaN  ...  221.8
# 4     Mean Number of Hours    *  136.6            NaN  ...  237.2
# ...                    ...  ...    ...            ...  ...    ...
# 1957  Mean Number of Hours    *  244.9            NaN  ...  272.8
# 1958  Mean Number of Hours    *    8.0            NaN  ...    8.4
# 1959  Mean Number of Hours    *  248.0            NaN  ...  260.4
# 1960  Mean Number of Hours    *    7.6            NaN  ...    8.0
# 1961  Mean Number of Hours    *  235.6            NaN  ...  248.0
#
#       Oct Footnotes    Nov  Nov Footnotes    Dec  Dec Footnotes  Annual  \
# 0               NaN  176.4            NaN  127.3            NaN   205.3
# 1               NaN  175.8            NaN  125.7            NaN   236.9
# 2               NaN  173.6            NaN  125.5            NaN   229.9
# 3               NaN  169.3            NaN  118.3            NaN   229.5
# 4               NaN  159.1            NaN  137.9            NaN   239.6
# ...             ...    ...            ...    ...            ...     ...
# 1957            NaN  237.0            NaN  226.3            NaN  3119.9
# 1958            NaN    7.6            NaN    7.0            NaN -9999.9
# 1959            NaN  228.0            NaN  217.0            NaN  2991.8
# 1960            NaN    7.6            NaN    6.8            NaN -9999.9
# 1961            NaN  228.0            NaN  210.8            NaN  2848.7
#
#       Annual Footnotes  Annual NCDC Computed Value  \
# 0                  NaN                      2576.6
# 1                  NaN                      2823.1
# 2                  NaN                      2762.9
# 3                  NaN                      2652.3
# 4                  NaN                      2866.9
# ...                ...                         ...
# 1957               NaN                      3119.9
# 1958               1.0                     -9999.9
# 1959               NaN                      2991.8
# 1960               1.0                     -9999.9
# 1961               NaN                      2848.7
#
#       Annual NCDC Computed Value Footnotes
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 1957                                   NaN
# 1958                                   1.0
# 1959                                   NaN
# 1960                                   1.0
# 1961                                   NaN
#
# [1962 rows x 36 columns]

# %%
df.columns
# Out:
# Index(['Country or Territory', 'Station Name', 'WMO Station Number',
#        'National Station Id Number', 'Period',
#        'Element-Statistic Qualifier Code', 'Statistic Description', 'Unit',
#        'Jan', 'Jan Footnotes', 'Feb', 'Feb Footnotes', 'Mar', 'Mar Footnotes',
#        'Apr', 'Apr Footnotes', 'May', 'May Footnotes', 'Jun', 'Jun Footnotes',
#        'Jul', 'Jul Footnotes', 'Aug', 'Aug Footnotes', 'Sep', 'Sep Footnotes',
#        'Oct', 'Oct Footnotes', 'Nov', 'Nov Footnotes', 'Dec', 'Dec Footnotes',
#        'Annual', 'Annual Footnotes', 'Annual NCDC Computed Value',
#        'Annual NCDC Computed Value Footnotes'],
#       dtype='object')

# %%
df["Aug"]
# Out:
# 0       305.2
# 1       346.1
# 2       332.7
# 3       315.5
# 4       352.5
#         ...
# 1957    300.7
# 1958      9.2
# 1959    285.2
# 1960      8.7
# 1961    269.7
# Name: Aug, Length: 1962, dtype: float64

# %%
print(f"max: %s"% df["Aug"].max() )
print(f"min: %s"% df["Aug"].min() )
# Out:
# max: 406.9
# min: -9999.9

# %%
df = df.replace(-9999.9, np.nan)

# %%
print(f"max: %s"% df["Aug"].max() )
print(f"min: %s"% df["Aug"].min() )
# Out:
# max: 406.9
# min: 1.4

# %%
df['Country or Territory'].unique()
# Out:
# array(['AFGHANISTAN, ISLAMIC STATE OF', 'ALBANIA', 'ARGENTINA',
#        'ARGENTINA (ANTARCTIC STATIONS)', 'ARMENIA', 'AUSTRALIA',
#        'AUSTRALIA (ANTARCTIC STATIONS)', 'AUSTRIA', 'AZERBAIJAN',
#        'BAHAMAS', 'BAHRAIN', 'BELARUS', 'BELGIUM', 'BELIZE', 'BENIN',
#        'BOSNIA AND HERZEGOVINA', 'BRAZIL', 'BRUNEI DARUSSALAM',
#        'BULGARIA', 'CAMEROON', 'CAPE VERDE', 'CHAD', 'CHINA', 'COLOMBIA',
#        'COLOMBIA (SAN ANDRES AND PROVIDENCIA ISLANDS)', 'COSTA RICA',
#        'CROATIA', 'CYPRUS', 'CZECH REPUBLIC', 'DENMARK', 'DJIBOUTI',
#        'DOMINICA', 'DOMINICAN REPUBLIC', 'EGYPT', 'ERITREA', 'ESTONIA',
#        'FIJI', 'FINLAND', 'FRANCE',
#        'FRANCE (CARIBBEAN ISLANDS, GUADELOUPE, MARTINIQUE)',
#        'FRANCE (FRENCH DEPARTMENT OF GUYANA)',
#        'FRANCE (ISLANDS IN THE INDIAN OCEAN)', 'FRENCH POLYNESIA',
#        'GABON', 'GEORGIA', 'GERMANY', 'GREECE', 'GREENLAND', 'GUINEA',
#        'GUYANA', 'HONDURAS', 'HONG KONG', 'HUNGARY', 'ICELAND', 'INDIA',
#        'IRAN, ISLAMIC REPUBLIC OF', 'ISRAEL', 'ITALY', 'IVORY COAST',
#        'JAPAN', 'JORDAN', 'KAZAKSTAN (ASIA)', 'KAZAKSTAN (EUROPE)',
#        'KENYA', 'KOREA, REPUBLIC OF', 'KUWAIT', 'KYRGYZ REPUBLIC',
#        "LAO PEOPLE'S DEMOCRATIC REPUBLIC", 'LATVIA', 'LITHUANIA',
#        'LUXEMBOURG', 'MADAGASCAR', 'MALAWI', 'MALAYSIA', 'MALDIVES',
#        'MALI', 'MAURITIUS', 'MEXICO', 'MOLDOVA, REPUBLIC OF', 'MONGOLIA',
#        'MOROCCO', 'NETHERLANDS', 'NETHERLANDS ANTILLES AND ARUBA',
#        'NEW CALEDONIA', 'NICARAGUA', 'NIGER', 'NIGERIA', 'NORWAY', 'OMAN',
#        'PAKISTAN', 'POLAND', 'PORTUGAL', 'PORTUGAL (MADEIRA)', 'QATAR',
#        'ROMANIA', 'RUSSIAN FEDERATION (ASIA)',
#        'RUSSIAN FEDERATION (EUROPE)', 'SENEGAL', 'SEYCHELLES',
#        'SIERRA LEONE', 'SINGAPORE', 'SLOVAKIA', 'SLOVENIA',
#        'SOUTH AFRICA', 'SPAIN',
#        'SPAIN (CANARY ISLANDS, CEUTA AND MELILLA)', 'SRI LANKA', 'SWEDEN',
#        'SWITZERLAND', 'SYRIAN ARAB REPUBLIC', 'TAJIKISTAN', 'THAILAND',
#        'THE FORMER YUGOSLAV REPUBLIC OF MACEDONIA', 'TOGO',
#        'TRINIDAD AND TOBAGO', 'TUNISIA', 'TURKMENISTAN', 'UKRAINE',
#        'UNITED ARAB EMIRATES',
#        'UNITED KINGDOM OF GREAT BRITAIN & NORTHERN IRELAND',
#        'UNITED STATES OF AMERICA',
#        'UNITED STATES OF AMERICA (PACIFIC ISLANDS)', 'URUGUAY',
#        'UZBEKISTAN', 'VENEZUELA', 'YUGOSLAVIA', 'ZAMBIA', 'ZIMBABWE'],
#       dtype=object)

# %%
all_country = ['AFGHANISTAN', 'ALBANIA', 'ARGENTINA', \
               'ARMENIA', 'AUSTRALIA', 'AUSTRIA', 'AZERBAIJAN',\
               'BAHAMAS', 'BAHRAIN', 'BELARUS', 'BELGIUM', 'BELIZE', 'BENIN',\
               'BOSNIA AND HERZEGOVINA', 'BRAZIL', 'BRUNEI DARUSSALAM',\
               'BULGARIA', 'CAMEROON', 'CAPE VERDE', 'CHAD', 'CHINA', \
               'COLOMBIA', 'COSTA RICA','CROATIA', 'CYPRUS', 'CZECH REPUBLIC',\
               'DENMARK', 'DJIBOUTI','DOMINICA', 'DOMINICAN REPUBLIC', \
               'EGYPT', 'ERITREA', 'ESTONIA', 'FIJI', 'FINLAND', 'FRANCE',\
               'FRENCH POLYNESIA', 'GABON', 'GEORGIA', 'GERMANY', 'GREECE', \
               'GREENLAND', 'GUINEA', 'GUYANA', 'HONDURAS', 'HONG KONG', \
               'HUNGARY', 'ICELAND', 'INDIA', 'IRAN, ISLAMIC REPUBLIC OF', \
               'ISRAEL', 'ITALY', 'IVORY COAST', 'JAPAN', 'JORDAN', \
               'KAZAKSTAN', 'KENYA', \
               'KOREA, REPUBLIC OF', 'KUWAIT', 'KYRGYZ REPUBLIC', \
               "LAO PEOPLE'S DEMOCRATIC REPUBLIC", 'LATVIA', 'LITHUANIA',\
               'LUXEMBOURG', 'MADAGASCAR', 'MALAWI', 'MALAYSIA', 'MALDIVES',\
               'MALI', 'MAURITIUS', 'MEXICO', 'MOLDOVA, REPUBLIC OF', 'MONGOLIA',\
               'MOROCCO', 'NETHERLANDS', 'NETHERLANDS ANTILLES AND ARUBA',\
               'NEW CALEDONIA', 'NICARAGUA', 'NIGER', 'NIGERIA', 'NORWAY', \
               'OMAN', 'PAKISTAN', 'POLAND', 'PORTUGAL', \
               'QATAR', 'ROMANIA', 'RUSSIAN', \
               'SENEGAL', 'SEYCHELLES', 'SIERRA LEONE', 'SINGAPORE', 'SLOVAKIA', \
               'SLOVENIA', 'SOUTH AFRICA', 'SPAIN', 'SRI LANKA', 'SWEDEN', \
               'SWITZERLAND', 'SYRIAN ARAB REPUBLIC', 'TAJIKISTAN', 'THAILAND', \
               'THE FORMER YUGOSLAV REPUBLIC OF MACEDONIA', 'TOGO', \
               'TRINIDAD AND TOBAGO', 'TUNISIA', 'TURKMENISTAN', 'UKRAINE', \
               'UNITED ARAB EMIRATES', 'UNITED KINGDOM', \
               'UNITED STATES OF AMERICA', \
               'URUGUAY', 'UZBEKISTAN', 'VENEZUELA', 'YUGOSLAVIA', 'ZAMBIA', 'ZIMBABWE']

# %%
all_months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', \
              'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# %%
temp = df.loc[df['Country or Territory'] == "ARGENTINA"]["Jan"]

# %%
np.array(temp)
# Out:
# array([192.2,   6.2, 164.3,   5.3, 272.8,   8.8, 229.4,   7.4,   nan,
#          nan, 279. ,   9. , 279. ,   9. , 223.2,   7.2, 244.9,   7.9,
#        275.9,   8.9, 275.9,   8.9,   nan,   nan, 266.6,   8.6, 244.9,
#          7.9, 257.3,   8.3, 275.9,   8.9, 291.4,   9.4, 282.1,   9.1,
#        297.6,   9.6, 251.1,   8.1, 319.3,  10.3, 294.5,   9.5,   nan,
#          nan, 263.5,   8.5, 294.5,   9.5, 297.6,   9.6, 266.6,   8.6,
#          nan,   nan,   nan,   nan, 294.5,   9.5,   nan,   nan, 291.4,
#          9.4,   nan,   nan, 251.1,   8.1,   nan,   nan, 251.1,   8.1,
#        291.4,   9.4, 319.3,  10.3,   nan,   nan, 266.6,   8.6, 300.7,
#          9.7, 220.1,   7.1, 313.1,  10.1,   nan,   nan, 347.2,  11.2,
#        306.9,   9.9, 310. ,  10. , 241.8,   7.8,   nan,   nan, 254.2,
#          8.2,   nan,   nan])

# %%
data_out = np.zeros([len(all_country), 4]) # ave sunshine hours, std, # data points, # pts with nan
for i, country in enumerate(all_country):
    hrs = np.array([])

    for d_country in df['Country or Territory'].unique():
        if country in d_country:
            for month in all_months:
                data = df.loc[df['Country or Territory'] == d_country][month]
                hrs = np.append(hrs, np.array(data))
    
    data_out[i, :] = [np.nanmean(hrs), np.nanstd(hrs), len(hrs), np.isnan(hrs).sum()]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: RuntimeWarning: Mean of empty slice
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.7/dist-packages/numpy/lib/nanfunctions.py:1671: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)

# %%
data_out
# Out:
# array([[ 249.63583333,   78.88361183,  240.        ,    0.        ],
#        [          nan,           nan,   72.        ,   72.        ],
#        [ 106.19949239,  106.4089022 , 1236.        ,  251.        ],
#        [ 204.79166667,   87.39611889,   24.        ,    0.        ],
#        [ 115.24713542,  117.65321689,  768.        ,    0.        ],
#        [ 148.23809524,   58.4212166 ,   84.        ,    0.        ],
#        [ 179.32314815,   74.95595078,  108.        ,    0.        ],
#        [ 123.875     ,  117.33115617,   24.        ,    0.        ],
#        [ 144.325     ,  138.65357085,   24.        ,    0.        ],
#        [ 148.5       ,   86.06562419,   48.        ,    0.        ],
#        [ 124.13333333,   53.51243365,   12.        ,    0.        ],
#        [ 212.87777778,   34.39298306,   12.        ,    3.        ],
#        [ 107.15833333,  106.00218676,  120.        ,    0.        ],
#        [ 147.45      ,   68.08978754,   12.        ,    0.        ],
#        [ 189.1835396 ,   47.4828216 , 2424.        ,    0.        ],
#        [ 213.16666667,   14.57642694,   12.        ,    0.        ],
#        [ 181.9047619 ,   82.87549742,   84.        ,    0.        ],
#        [ 186.62892562,   58.64374504,  132.        ,   11.        ],
#        [  68.3       ,   28.25417373,   12.        ,    0.        ],
#        [ 137.74583333,  132.56686671,  144.        ,    0.        ],
#        [ 200.1775463 ,   62.30986658,  432.        ,    0.        ],
#        [ 168.3004902 ,   42.50388852,  204.        ,    0.        ],
#        [  97.17222222,   97.09557751,   72.        ,    0.        ],
#        [ 183.05833333,   81.37933766,   24.        ,    0.        ],
#        [ 142.60833333,  143.3582195 ,   24.        ,    0.        ],
#        [ 132.00208333,   66.85107669,   48.        ,    0.        ],
#        [ 135.37777778,   78.49650775,  180.        ,    0.        ],
#        [ 272.15      ,   23.66352679,   12.        ,    0.        ],
#        [ 235.775     ,   25.47971675,  180.        ,   48.        ],
#        [ 237.44083333,   25.45282072,  168.        ,   48.        ],
#        [ 289.05902778,   56.6188075 ,  144.        ,    0.        ],
#        [ 125.75416667,  122.06180804,   24.        ,    0.        ],
#        [ 149.08333333,   98.56445297,   48.        ,    0.        ],
#        [ 176.8625    ,   39.40160543,   24.        ,    0.        ],
#        [ 138.70333333,   94.54474067,  120.        ,    0.        ],
#        [ 168.19567901,   80.69295627,  324.        ,    0.        ],
#        [ 211.89166667,   28.61174972,   96.        ,    0.        ],
#        [ 122.78571429,   32.93638942,   84.        ,    0.        ],
#        [ 165.54166667,   54.86269161,   24.        ,    0.        ],
#        [ 135.93859649,   65.83988221,  228.        ,    0.        ],
#        [ 221.03229167,   87.17779904,   96.        ,    0.        ],
#        [ 131.15625   ,  100.72635456,   96.        ,    0.        ],
#        [ 204.41666667,   47.0492502 ,   72.        ,    0.        ],
#        [ 186.02333333,   44.63286295,   60.        ,    0.        ],
#        [ 229.28333333,   32.3802752 ,   24.        ,    0.        ],
#        [ 162.34166667,   41.28525682,   12.        ,    0.        ],
#        [ 161.28809524,   78.8781737 ,   84.        ,    0.        ],
#        [  96.40833333,   61.85093584,   24.        ,    0.        ],
#        [ 209.55541667,   63.41574768,  240.        ,    0.        ],
#        [ 235.51071429,   72.48515163,  336.        ,    0.        ],
#        [ 279.4625    ,   65.69281298,   24.        ,    0.        ],
#        [  97.70196078,  104.17722196,  816.        ,    0.        ],
#        [ 177.31333333,   44.58626458,  120.        ,    0.        ],
#        [ 152.65488323,   39.65541468, 1884.        ,    0.        ],
#        [ 142.27291667,  142.42336205,   96.        ,    0.        ],
#        [ 215.40123457,   92.08429846,  324.        ,    0.        ],
#        [ 126.6725    ,  122.50837248,  120.        ,    0.        ],
#        [ 180.4       ,   32.57520998,  144.        ,    0.        ],
#        [ 129.40833333,  124.02292099,   24.        ,    0.        ],
#        [ 214.91666667,   72.70426206,   24.        ,    0.        ],
#        [ 196.09166667,   44.95881062,   36.        ,    0.        ],
#        [ 143.4375    ,   91.82000196,   48.        ,    0.        ],
#        [ 144.4375    ,   88.5776275 ,   48.        ,    0.        ],
#        [ 135.85      ,   67.12803066,   12.        ,    0.        ],
#        [ 241.88392857,   44.45125518,  168.        ,    0.        ],
#        [ 120.31666667,  117.44661246,  360.        ,    0.        ],
#        [ 191.97142857,   32.58286532,  168.        ,    0.        ],
#        [ 231.51666667,   22.35031071,   12.        ,    0.        ],
#        [ 250.61658986,   26.32209041,  228.        ,   11.        ],
#        [ 230.95833333,   30.38705751,   24.        ,    0.        ],
#        [ 211.18240741,   37.40125228,  108.        ,    0.        ],
#        [ 177.16666667,   89.26536594,   12.        ,    0.        ],
#        [ 244.60166667,   49.758667  ,  180.        ,    0.        ],
#        [ 251.33571429,   49.54703788,  168.        ,    0.        ],
#        [ 159.81071429,   76.8680936 ,   84.        ,    0.        ],
#        [ 250.16666667,   15.6142741 ,   24.        ,    0.        ],
#        [ 207.14833333,   27.04267302,   60.        ,    0.        ],
#        [ 202.34444444,   35.71206958,   72.        ,    0.        ],
#        [ 124.33484848,  122.48024886,  528.        ,    0.        ],
#        [ 103.045     ,  103.43857102,  240.        ,    0.        ],
#        [  99.76666667,   76.12278824,   60.        ,    0.        ],
#        [ 197.03722222,   86.9337775 ,  180.        ,    0.        ],
#        [ 254.05634921,   43.39640739,  252.        ,    0.        ],
#        [ 125.61666667,   67.01780651,  120.        ,    0.        ],
#        [ 202.64102564,   73.3004835 ,  156.        ,    0.        ],
#        [ 147.7375    ,  141.09836643,   24.        ,    0.        ],
#        [ 169.51969697,   78.9956802 ,  132.        ,    0.        ],
#        [ 160.37564103,   92.34429911, 2340.        ,    0.        ],
#        [ 129.42592593,  122.66755727,  216.        ,    0.        ],
#        [ 210.64166667,   28.97468603,   12.        ,    0.        ],
#        [  86.45902778,   87.24532176,  144.        ,    0.        ],
#        [ 168.53333333,   19.67321925,   12.        ,    0.        ],
#        [ 148.25555556,   64.33994977,   36.        ,    0.        ],
#        [ 142.675     ,   73.65165901,   12.        ,    0.        ],
#        [ 236.56666667,   65.18881485,  156.        ,    0.        ],
#        [ 211.89671717,   69.06887548,  396.        ,    0.        ],
#        [ 112.81666667,  107.16144233,   24.        ,    0.        ],
#        [ 141.83333333,   89.54726664,  108.        ,    0.        ],
#        [ 145.74375   ,   54.14430143,   48.        ,    0.        ],
#        [ 132.45972222,  136.32789006,  216.        ,    0.        ],
#        [ 224.91666667,   87.06459128,   12.        ,    0.        ],
#        [ 220.29215686,   45.22033246,  204.        ,    0.        ],
#        [ 183.75208333,   79.11032642,   48.        ,    0.        ],
#        [ 205.44166667,   47.44345245,   48.        ,    0.        ],
#        [ 112.34166667,  106.09456441,   24.        ,    0.        ],
#        [ 132.38035714,  131.58141525,  168.        ,    0.        ],
#        [ 241.57777778,   87.6400787 ,  108.        ,    0.        ],
#        [ 171.11111111,   89.87955761,  144.        ,    0.        ],
#        [ 150.38416667,  143.21290794,  120.        ,    0.        ],
#        [ 118.68791667,   55.99467515,  240.        ,    0.        ],
#        [ 226.15664683,   71.26408991, 2016.        ,    0.        ],
#        [ 205.78939394,   48.012939  ,  132.        ,    0.        ],
#        [ 236.59583333,   99.16163774,   72.        ,    0.        ],
#        [ 111.61125   ,  107.58338626,  480.        ,    0.        ],
#        [ 187.73333333,   78.01539734,   24.        ,    0.        ],
#        [ 237.75033333,   56.55890233,  300.        ,    0.        ],
#        [ 128.86319444,  122.73908174,  144.        ,    0.        ]])

# %%
df_out = pd.DataFrame(data_out, \
                      columns = ["ave sunshine hours per month", "std", "total data points", "bad data points"], \
                      index = all_country)

# %%
df_out
# Out:
#              ave sunshine hours per month         std  total data points  \
# AFGHANISTAN                    249.635833   78.883612              240.0
# ALBANIA                               NaN         NaN               72.0
# ARGENTINA                      106.199492  106.408902             1236.0
# ARMENIA                        204.791667   87.396119               24.0
# AUSTRALIA                      115.247135  117.653217              768.0
# ...                                   ...         ...                ...
# UZBEKISTAN                     236.595833   99.161638               72.0
# VENEZUELA                      111.611250  107.583386              480.0
# YUGOSLAVIA                     187.733333   78.015397               24.0
# ZAMBIA                         237.750333   56.558902              300.0
# ZIMBABWE                       128.863194  122.739082              144.0
#
#              bad data points
# AFGHANISTAN              0.0
# ALBANIA                 72.0
# ARGENTINA              251.0
# ARMENIA                  0.0
# AUSTRALIA                0.0
# ...                      ...
# UZBEKISTAN               0.0
# VENEZUELA                0.0
# YUGOSLAVIA               0.0
# ZAMBIA                   0.0
# ZIMBABWE                 0.0
#
# [117 rows x 4 columns]

# %%
cleandata_path = data_path+'/Cleaned_feature_data'
df_out.to_csv(cleandata_path+'/sunshine_clean.csv', index=False)
